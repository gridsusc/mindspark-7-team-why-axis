# %%
# Import Library
import pandas as pd
import dash
import dash_core_components as dcc
import dash_html_components as html
import dash_table
import numpy as np
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from dash.dependencies import Input, Output, State
from io import BytesIO
import requests
from jupyter_dash import JupyterDash
import dash_bootstrap_components as dbc
import plotly.express as px
import dash_table as dt
#import dash_colorscales
# Out:
# <ipython-input-1-935a81a38f82>:4: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# <ipython-input-1-935a81a38f82>:5: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# <ipython-input-1-935a81a38f82>:6: UserWarning:
# The dash_table package is deprecated. Please replace
# `import dash_table` with `from dash import dash_table`
#
# Also, if you're using any of the table format helpers (e.g. Group), replace
# `from dash_table.Format import Group` with
# `from dash.dash_table.Format import Group`
#   import dash_table

# %%
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']
app = JupyterDash(__name__,external_stylesheets=[dbc.themes.DARKLY])

# %%
filename= 'rf_project.sav'
rfc= pickle.load(open(filename, 'rb'))

# %%
app.layout = html.Div([
    #html.H1('TURNOVER DASHBOARD'),
    html.H1('Employee inclination to seek help', style={'fontSize':40,'width':'100%', 'height': '100%','margin':25, 'textAlign': 'center','color': '#89AEDB'}),
    dcc.Tabs(id="tabs-example-graph", value='tab-2-example-graph', children=[
        
#         dcc.Tab(label='Attrition',value='tab-1-example-graph',
#                 style={ 'textAlign': 'center','color': '#89AEDB','background': '#272E3E','fontSize': '50'},
#                 selected_style = {'backgroundColor': '#272E3E',
#     'color': '#89AEDB','borderTop': '3px solid #d6d6d6',}),
        dcc.Tab(label='Confidential', value='tab-2-example-graph',
                style={'textAlign': 'center','color': '#89AEDB','background': '#272E3E','fontSize': '50','height':'10px'},
                selected_style = {'backgroundColor': '#272E3E',
    'color': '#89AEDB','borderTop': '3px solid #d6d6d6'}),
       
    ],
        colors={
        "border": "#272E3E",
        "primary": "272E3E",
        "background": "#272E3E"
    },
            ),
    html.Div(id='tabs-content-example-graph'),
    
    
])

# %%
@app.callback(Output('tabs-content-example-graph', 'children'),
              Input('tabs-example-graph', 'value'))
def render_content(tab):
     if tab == 'tab-2-example-graph':
            return html.Div(children=[ #children is to make child HTML tags
        html.H1('Input below indicators',style = {
                                                    'textAlign':'center','color': '#89AEDB',
                                                    'fontSize':30,'background': '#272E3E',
                                                }), #H1 is for website header
        html.Div([
            html.Div([
                html.Div(id='output_gender', style={'font-weight': 'bold','color': '#89AEDB'}),
                dcc.Dropdown(
                    id='gender',
                    options=[
                        {'label': 'others', 'value': 'others'},
                        {'label': 'male', 'value': 'male'},
                        {'label': 'female', 'value': 'female'}
                    ],value='female' ,style={'color': '#89AEDB','background': '#89AEDB', }
                ),
                
                html.Div(id='out-all-types', style={'font-weight': 'bold', 'color': '#89AEDB'}),
                dcc.Input(
                    id="input_{}".format("number"),
                    type="number",
                    placeholder="age {}".format("number"),
                    value = 30,style={'color': 'black','background': '#89AEDB', }),

                html.Div(id='output_fam_hist', style={'font-weight': 'bold','color': '#89AEDB'}),
                dcc.Dropdown(
                    id='fam_hist',
                    options=[
                        {'label': 'Yes', 'value': 'Yes'},
                        {'label': 'No', 'value': 'No'},
                        {'label': 'Maybe', 'value': 'Maybe'}
                    ],value='Yes' ,style={'color': '#89AEDB','background': '#89AEDB', }
                ),
                

                
                html.Div(id='output_work_interfere', style={'font-weight': 'bold','color': '#89AEDB'}),
                dcc.Dropdown(
                    id='work_interfere',
                    options=[
                        {'label': 'Never', 'value': 'Never'},
                        {'label': 'Rarely', 'value': 'Rarely'},
                        {'label': 'Not applicable to me', 'value': 'Not applicable to me'},
                        {'label': 'Sometimes', 'value': 'Sometimes'},
                        {'label': 'Often', 'value': 'Often'}
                    ],value = 'Sometimes', style={'color': '#89AEDB','background': '#89AEDB', }
                ),
#                  html.Div(id='output_work_interfere', style={'font-weight': 'bold','color': '#89AEDB'}),
#                 dcc.Slider('Never','Rarely','Not applicable to me','Sometimes','Often',
#                     id='work_interfere',
#                     value = 'Sometimes', style={'color': '#89AEDB','background': '#89AEDB', }
#                 ),


                html.Div(id='output_no_employees', style={'font-weight': 'bold','color': '#89AEDB'}),
                dcc.Dropdown(
                    id='no_employees',
                    options=[
                        {'label': '1-5', 'value': '1-5'},
                        {'label': '6-25', 'value': '6-25'},
                        {'label': '26-100', 'value': '26-100'},
                        {'label': '100-500', 'value': '100-500'},
                        {'label': '500-1000', 'value': '500-1000'},
                        {'label': 'More than 1000', 'value': 'More than 1000'}
                    ],value = '6-25', style={'color': '#89AEDB','background': '#89AEDB', }
                ),
                
                html.Div(id='output_ment_health_benefits', style={'font-weight': 'bold','color': '#89AEDB'}),
                dcc.Dropdown(
                    id='ment_health_benefits',
                    options=[
                        {'label': 'Yes', 'value': 'Yes'},
                        {'label': 'No', 'value': 'No'},
                        {'label': 'Maybe', 'value': 'Maybe'}
                    ],value='Yes' ,style={'color': '#89AEDB','background': '#89AEDB', }
                ),
                
                html.Div(id='output_anonymity', style={'font-weight': 'bold','color': '#89AEDB'}),
                dcc.Dropdown(
                    id='anonymity',
                    options=[
                        {'label': 'Yes', 'value': 'Yes'},
                        {'label': 'No', 'value': 'No'},
                        {'label': 'Maybe', 'value': 'Maybe'}
                    ],value='Yes' ,style={'color': '#89AEDB','background': '#89AEDB', }
                ),


                
    #################   
            ], className="six columns",style={'width': '49%', 'display': 'inline-block','height': '100vh'}),
            html.Div([
                html.Div(id='output_employer_option_awareness', style={'font-weight': 'bold', 'color': '#89AEDB'}),
                dcc.Dropdown(
                    id='employer_option_awareness',
                    options=[
                        {'label': 'Yes', 'value': 'Yes'},
                        {'label': 'No', 'value': 'No'},
                        {'label': 'Maybe', 'value': 'Maybe'}
                    ],value='No',style={'color': '#89AEDB','background': '#89AEDB', }
                ),
                
                html.Div(id='output_wellness_program_include', style={'font-weight': 'bold', 'color': '#89AEDB'}),
                dcc.Dropdown(
                    id='wellness_program_include',
                    options=[
                        {'label': 'Yes', 'value': 'Yes'},
                        {'label': 'No', 'value': 'No'},
                        {'label': 'Maybe', 'value': 'Maybe'}
                    ],value='No',style={'color': '#89AEDB','background': '#89AEDB', }
                ),
                
                html.Div(id='output_phy_interview', style={'font-weight': 'bold', 'color': '#89AEDB'}),
                dcc.Dropdown(
                    id='phy_interview',
                    options=[
                        {'label': 'Yes', 'value': 'Yes'},
                        {'label': 'No', 'value': 'No'},
                        {'label': 'Maybe', 'value': 'Maybe'}
                    ],value='No',style={'color': '#89AEDB','background': '#89AEDB', }
                ),  
            
                html.Div(id='output_neg_conseq_coworkers', style={'font-weight': 'bold', 'color': '#89AEDB'}),
                dcc.Dropdown(
                    id='neg_conseq_coworkers',
                    options=[
                        {'label': 'Yes', 'value': 'Yes'},
                        {'label': 'No', 'value': 'No'},
                        {'label': 'Maybe', 'value': 'Maybe'}
                    ],value='No',style={'color': '#89AEDB','background': '#89AEDB', }
                ),  
                
                html.Div(id='output_leave', style={'font-weight': 'bold', 'color': '#89AEDB'}),
                dcc.Dropdown(
                    id='leave',
                    options=[
                        {'label': 'Easy', 'value': 'Easy'},
                        {'label': 'Maybe', 'value': 'Maybe'},
                        {'label': 'Difficult', 'value': 'Difficult'}
                    ],value='Easy',style={'color': '#89AEDB','background': '#89AEDB', }
                ),  
            
                html.Div(id='output_coworkers_dis', style={'font-weight': 'bold', 'color': '#89AEDB'}),
                dcc.Dropdown(
                    id='coworkers_dis',
                    options=[
                        {'label': 'Yes', 'value': 'Yes'},
                        {'label': 'No', 'value': 'No'},
                        {'label': 'Maybe', 'value': 'Maybe'}
                    ],value='No',style={'color': '#89AEDB','background': '#89AEDB', }
                ),  
                
                html.Div(id='output_supervisor_disc', style={'font-weight': 'bold', 'color': '#89AEDB'}),
                dcc.Dropdown(
                    id='supervisor_disc',
                    options=[
                        {'label': 'Yes', 'value': 'Yes'},
                        {'label': 'No', 'value': 'No'},
                        {'label': 'Maybe', 'value': 'Maybe'}
                    ],value='No',style={'color': '#89AEDB','background': '#89AEDB', }
                ), 

                html.H3(id='pred_result', style={'font-weight': 'bold', 'color': '#89AEDB'})
            ], className = "six columns", style={'width': '50%', 'float': 'right', 'display': 'inline-block','height' : '80vh'}),
        ], className = "row",style ={'display': 'inline-block','width': '100%','height':'100%'})
    ################# 
    ], style={'padding': '15px 10px','height':'100vh'})

        
##################
@app.callback(
    Output('output_gender', 'children'),
    [Input('gender', 'value')])
def update_output(value):
    return 'Gender: {}'.format(value)

@app.callback(
    Output('output_fam_hist', 'children'),
    [Input('fam_hist', 'value')])
def update_output(value):
    return 'Mental health history in Family: {} '.format(value)
    
@app.callback(
    Output('output_work_interfere', 'children'),
    [Input('work_interfere', 'value')])
def update_output(value):
    return 'Does mental health interfere with work: {}'.format(value)  

@app.callback(
    Output('output_no_employees', 'children'),
    [Input('no_employees', 'value')])
def update_output(value):
    return '#Employees: {} '.format(value)
    
@app.callback(
    Output('output_ment_health_benefits', 'children'),
    [Input('ment_health_benefits', 'value')])
def update_output(value):
    return 'Does emoloyer provide mental health benefits: {} '.format(value)

@app.callback(
    Output('output_employer_option_awareness', 'children'),
    [Input('employer_option_awareness', 'value')])
def update_output(value):
    return 'Awareness of mental health benefits by employer: {} '.format(value)


##########
@app.callback(
    Output('output_wellness_program_include', 'children'),
    [Input('wellness_program_include', 'value')])
def update_output(value):
    return 'Mental health inclusion in employee wellness programs: {} '.format(value)
    
@app.callback(
    Output('output_phy_interview', 'children'),
    [Input('phy_interview', 'value')])
def update_output(value):
    return 'Would you declare physical issues with potential employer: {} '.format(value)
    
@app.callback(
    Output('output_neg_conseq_coworkers', 'children'),
    [Input('neg_conseq_coworkers', 'value')])
def update_output(value):
    return 'Obs Neg impact on coworkers with mental health conditions: {}'.format(value)
    

@app.callback(
    Output('output_leave', 'children'),
    [Input('leave', 'value')])
def update_output(value):
    return 'Is it easy to get a leave for mental health issues: {} '.format(value)
    
@app.callback(
    Output('output_coworkers_dis', 'children'),
    [Input('coworkers_dis', 'value')])
def update_output(value):
    return 'Would you discuss mental health issue with coworkers: {}'.format(value)

@app.callback(
    Output('output_anonymity', 'children'),
    [Input('anonymity', 'value')])
def update_output(value):
    return 'Is your anonymity protected if you use mental health resources: {}'.format(value)

@app.callback(
    Output('output_supervisor_disc', 'children'),
    [Input('supervisor_disc', 'value')])
def update_output(value):
    return 'Would you discuss mental health issue with supervisor: {}'.format(value)

@app.callback(
    Output('out-all-types', 'children'),
    [Input("input_{}".format("number"), "value")])
def update_output(value):
    return 'Age: {} '.format(value)
    
##################


@app.callback(
    Output('pred_result', 'children'),
    [Input("input_{}".format("number"), 'value'),
    Input('gender', 'value'),
     Input('fam_hist', 'value'),
    Input('work_interfere', 'value'),
    Input('no_employees', 'value'),
    Input('ment_health_benefits', 'value'),
    Input('employer_option_awareness', 'value'),
    Input('wellness_program_include', 'value'),
    Input('phy_interview', 'value'),
    Input('neg_conseq_coworkers', 'value'),
    Input('anonymity', 'value'),
    Input('leave', 'value'),
    Input('coworkers_dis', 'value'),
    Input('supervisor_disc', 'value')])
  

def update_prediction(x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11,x12,x13,x14):
    
    
    # Create a NumPy array in the form of the original features
    input_X = pd.DataFrame({'age':[x1],
                        'gender':[x2],
                        'family_history':[x3],
                        'work_interfere':[x4],
                        'no_employees':[x5],
                        'ment_health_benefits':[x6],
                        'employer_option_awareness':[x7],
                        'wellness_program_include':[x8],
                        'phy_interview':[x9],
                        'neg_conseq_coworkers':[x10],
                        'anonymity':[x11],
                        'leave':[x12],
                        'coworkers_dis':[x13],
                        'supervisor_disc':[x14]
                       })

    predictions= rfc.predict_proba(input_X)[0][1]
    predictions = round(predictions*100,0)
    return 'Willingness of the employee to sort treatment for mental health : {}%'.format(predictions)

# @app.callback(
#     Output('pred_result','style'),
#     [Input('pred_result','children')]
# )
# def color_text(pred_result):
#     output = pred_result
#     if int(output[-3:-1])>10:
#         color = {'color':'red'}
#     else: 
#         color = {'color':'black'} 
#     return color
    


if __name__ == '__main__':
    app.run_server(mode='external', height= 500, width = '100%',port=8025,dev_tools_ui=False, debug = True)
# Out:
# Dash app running on http://127.0.0.1:8025/

# %% [markdown]
# input_X = pd.DataFrame({'age':[30],
#                     'gender':['female'],
#                     'family_history':['Yes'],
#                     'work_interfere':['Often'],
#                     'no_employees':['100-500'],
#                     'ment_health_benefits':['Yes'],
#                     'employer_option_awareness':['Yes'],
#                     'wellness_program_include':['Yes'],
#                     'phy_interview':['Maybe'],
#                     'neg_conseq_coworkers':['No'],
#                     'anonymity':['No'],
#                     'leave':['No'],
#                     'coworkers_dis':['No'],
#                     'supervisor_disc':['No']
#                    })
#
# predictions= rfc.predict_proba(input_X)[0][1]
# predictions = round(predictions*100,0)

# %% [markdown]
# predictions
